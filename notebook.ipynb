# %%
import matplotlib
import numpy as np
import cv2
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %%
img = cv2.imread('./ext/kt_images/45, X, Monosomy X/ZWK99002o.jpeg')
cv2.imwrite("org.jpg", img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
if img is None:
    assert False

# remove noise
img = cv2.GaussianBlur(img,(5,5),sigmaX=50)
cv2.imwrite("GaussianBlur.jpg", img)
weight = 0.9
print("ORG -> ", img)
img = img.astype(np.float)
print("Float -> ", img)
img = img - weight*img
print("Mul -> ", img)
img = img /(1.0 - weight)
print("Div -> ", img)
cv2.imwrite("after.jpg", img)
imshow(np.asarray(img), aspect='auto',cmap='gray', vmin=0, vmax=255)
# Out:
# ORG ->  [[253 253 253 ... 253 253 253]
#  [253 253 253 ... 253 253 253]
#  [253 253 253 ... 253 253 253]
#  ...
#  [253 253 253 ... 253 253 253]
#  [253 253 253 ... 253 253 253]
#  [253 253 253 ... 253 253 253]]
# Float ->  [[253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  ...
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]]
# Mul ->  [[25.3 25.3 25.3 ... 25.3 25.3 25.3]
#  [25.3 25.3 25.3 ... 25.3 25.3 25.3]
#  [25.3 25.3 25.3 ... 25.3 25.3 25.3]
#  ...
#  [25.3 25.3 25.3 ... 25.3 25.3 25.3]
#  [25.3 25.3 25.3 ... 25.3 25.3 25.3]
#  [25.3 25.3 25.3 ... 25.3 25.3 25.3]]
# Div ->  [[253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  ...
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]
#  [253. 253. 253. ... 253. 253. 253.]]
