# %%
import matplotlib
import numpy as np
import cv2

# %%
img = cv2.imread('/home/sss/Desktop/Projects/kt/ext/kt_images/t/ZWK99001o.jpeg')
img = cv2.Canny(img,10,100)

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %%
imshow(np.asarray(img), aspect='auto')
